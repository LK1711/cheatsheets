# %% [markdown]
# # Use Jupyter for Documention of Python Scripts
#
# ## Markdown
#
# ## Python
#
# ## Bash
#
# Use ```!``` to execute bash-commands.
# For example:

# %%
# !conda list
# Out:
# # packages in environment at /home/olimjon/anaconda3/envs/py27:
# #
# # Name                    Version                   Build  Channel
# backports                 1.0              py27h63c9359_1
# backports-abc             0.5                       <pip>
# backports.shutil-get-terminal-size 1.0.0                     <pip>
# backports.shutil_get_terminal_size 1.0.0            py27h5bc021e_2
# backports_abc             0.5              py27h7b3c97b_0
# bleach                    2.1.3                    py27_0
# ca-certificates           2018.03.07                    0
# certifi                   2018.4.16                py27_0
# configparser              3.5.0            py27h5117587_0
# decorator                 4.3.0                    py27_0
# decorator                 4.3.0                     <pip>
# entrypoints               0.2.3            py27h502b47d_2
# enum34                    1.1.6                     <pip>
# enum34                    1.1.6            py27h99a27e9_1
# ...
